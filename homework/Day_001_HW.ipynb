# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # 作業一
# <br><br>
#  Q1 你選的這組資料為何重要？：
# <br><br>
# https://www.kaggle.com/ronitf/heart-disease-uci#heart.csv
# <br>
# 對於預防心臟病可能有很大貢獻
# <br><br>
# Q2 資料從何而?:
# <br><br>
# 心臟病病人的數據
# <br><br>
# Q3 蒐集而來的資料型態為何?:
# <br><br>
# 每個病人可以分析出14種屬性
# <br>
# 最後存成.csv檔
# <br><br>
# Q4 這組資料想解決的問題如何評估?:
# <br><br>
# 檢測者的各項指數數值如果很接近心臟病患者的指數數值，就必須多加留意罹患心臟病的風險

# %% [markdown]
# # 作業二
# <br><br>
#  Q1 核心問題為何？：
# <br><br>
# 假設會叫車的客人在選擇車隊時只會考量各車隊司機的素質
# 假設天氣、地點與時間對於哪裡有人想搭車影響很大
# <br><br>
# Q2 資料從何而來？：
# <br><br>
# 使用APP叫車系統並有每個人的搭車紀錄(包含上下車地點及當時天氣)以及搭乘體驗分數
# 利用氣象台預測
# <br><br>
# Q3 蒐集而來的資料型態為何？：
# <br><br>
# 時間 datetime
# 地點 nvarchar
# 搭乘分數平均 decimal
# <br><br>
# Q4 你要回答的問題，其如何評估？：
# <br><br>
# 把低於標準值的駕駛教育訓練，限定期間內沒有改善則處罰或開除
# 在特定時間天氣地點預測人會比較多的時候多派人手過去

# %% [markdown]
# # 作業三 </font>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse
    
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 222.075
# The Mean absolute error is 12.123
